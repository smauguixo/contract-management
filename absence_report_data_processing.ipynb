# %% [markdown]
# # Healthcare Absence Management Pipeline
#
# ## Introduction
#
# In large public healthcare systems, managing healthcare contracts and tracking personnel data, including absences, is a complex and time-consuming task. This project automates the process of handling absence reports and professional records within a public-private healthcare contract. By developing a robust data pipeline, this project seeks to minimize manual effort, reduce errors, and generate reliable reports to support decision-making.
#
# The core objective of this notebook is to demonstrate a complete data processing pipeline, which includes:
# - **Data Integration**: Merging absence reports with facility information to create a unified dataset.
# - **Data Cleaning and Normalization**: Standardizing and cleaning the data to ensure consistency.
# - **Business Rule Application**: Implementing business logic, such as reclassifying medical leave and handling special cases.
# - **Data Consolidation**: Aggregating professional records and absences to create a comprehensive report.
# - **Automated Report Generation**: Generating detailed absence and professional reports that facilitate compliance monitoring and contract management.
#
# ### Key Outcomes:
# - Consolidated absence reports that simplify the analysis of employee absences.
# - Professional reports with a new field `LEGAL_ABSENCES`, automating a previously manual process of validating and documenting absences.
# - Insightful reports that can be used by managers to track and manage personnel more effectively.
#
# This notebook provides a step-by-step implementation of the pipeline, with code, explanations, and visualizations to help understand each stage of the process. You can follow the notebook to see how raw data is transformed into actionable reports.

# %%
import polars as pl
from unidecode import unidecode
from scripts.utils import (
    rename_absence_report_columns,
    PROFESSIONALS_COLS, 
    AUSENCIAS_COLS,
    ABSENCE_REPORT_PATH, 
    FACILITY_ID_PATH,
    EXCLUDED_PROFESSIONALS_PATH, 
    CONSOLIDATION_FAILURES_PATH, 
    ABSENCES_CONSOLIDATED_PATH, 
    PROFESSIONALS_CONSOLIDATED_PATH,
    configure_notebook_display,
    display_df,
    display_message,
)

# Configure notebook display settings for better readability
configure_notebook_display()

# Load data using Polars from Parquet files for optimal performance.
# We use scan_parquet to start in "lazy" mode, which optimizes memory and execution.
absence_report_lazy = pl.scan_parquet(ABSENCE_REPORT_PATH)
facility_id_lookup = pl.read_parquet(FACILITY_ID_PATH)

# Display a sample of the facility lookup table
display_df(facility_id_lookup.head(3))
# Out:
# shape: (3, 2)
# ┌───────────────┬──────────────────────────────┐
# │ rel_2141_CNES ┆ rel_2141_UNIDADE             │
# │ ---           ┆ ---                          │
# │ i64           ┆ str                          │
# ╞═══════════════╪══════════════════════════════╡
# │ 2027070       ┆ AMA PADRE MANOEL DA NOBREGA  │
# │ 2027070       ┆ UBS PADRE MANOEL DA NOBREGA  │
# │ 2029626       ┆ CAPS ADULTO III VILA MATILDE │
# └───────────────┴──────────────────────────────┘

# %% [markdown]
# ### Data Transformation: Indexing healthcare facilities with a lookup table
#
# One of the primary goals of this project is to integrate multiple datasets into a unified database. To achieve this, we standardize the column names in the `absence_report` by applying the prefix `rel_2141_` to each column. This naming convention helps track the origin of each piece of information once the data is consolidated.
#
# In this step, we also merge the `absence_report` with the `facility_id_lookup` table. This table contains two key columns:
# - `rel_2141_CNES`: The **National Health Establishment Code** (CNES), a unique identifier for each healthcare facility, which is not present in the absence report.
# - `rel_2141_UNIDADE`: The name of the healthcare facility, with normalized text for consistency.
#
# The merge is necessary because the facility names differ slightly across datasets, and only the CNES provides a reliable way to link records across databases.

# %%
# Start building the lazy query plan
absence_report_lazy = rename_absence_report_columns(absence_report_lazy)

# Define columns for text normalization.
text_cols = ['rel_2141_NOME', 'rel_2141_CARGO', 'rel_2141_UNIDADE', 'rel_2141_HORARIO']

# Define the business logic to unify employee statuses. This logic was missing and is now restored.
status_map = {
    'Férias': 'Ativo',
    'Aviso Prévio': 'Ativo',
    'Af.Ac.Trabalho': 'Af.Previdência',
    'Doença Ocupacional': 'Af.Previdência',
    'Licença Mater.': 'Af.Previdência'
}

# Chain operations in the lazy plan
absence_report_lazy = (
    absence_report_lazy
    .with_columns([
        # Normalize only the specified text fields
        pl.col(c).cast(pl.String).map_elements(lambda s: ' '.join(unidecode(s).strip().upper().split()) if s is not None else None, return_dtype=pl.String).alias(c) for c in text_cols
    ])
    .with_columns([
        # Clean specific patterns from CARGO and HORARIO columns
        pl.col('rel_2141_CARGO').str.replace_all(r' (I|II|III|-\\s*HC|-\\s*CER|-\\s*PAI|-\\s*SRT)$', ''),
        pl.col('rel_2141_HORARIO').str.replace_all(r'_.*?_', '').str.replace(' - APRENDIZ', '')
    ])
    .with_columns(
        # Apply the status mapping to the employee status column
        pl.col('rel_2141_STATUS').replace(status_map)
    )
    # Join with the facility lookup table
    .join(facility_id_lookup.lazy(), on='rel_2141_UNIDADE', how='left')
    # Select and reorder columns
    .select(AUSENCIAS_COLS)
)

# Execute the full lazy plan to get a concrete DataFrame
absence_report = absence_report_lazy.collect()

# Display a sample of the transformed data using the custom formatting function
display_df(absence_report.head(3))
# Out:
# shape: (13, 3)
# ┌──────────────────────┬────────────────┬─────────────────────────────────┐
# │ Column               ┆ Non-Null Count ┆ Dtype                           │
# │ ---                  ┆ ---            ┆ ---                             │
# │ str                  ┆ i64            ┆ object                          │
# ╞══════════════════════╪════════════════╪═════════════════════════════════╡
# │ rel_2141_CNES        ┆ 2725           ┆ Int64                           │
# │ rel_2141_UNIDADE     ┆ 2788           ┆ String                          │
# │ rel_2141_NOME        ┆ 2788           ┆ String                          │
# │ rel_2141_CARGO       ┆ 2788           ┆ String                          │
# │ rel_2141_DT_ADMISSAO ┆ 2788           ┆ Datetime(time_unit='ns', time_… │
# │ rel_2141_DT_DEMISSAO ┆ 93             ┆ String                          │
# │ rel_2141_prof_ID     ┆ 2788           ┆ Int64                           │
# ...

# %% [markdown]
# ### Absence Report Overview
#
# This dataset contains a comprehensive list of professionals currently employed by the social organization responsible for managing public health policies in a territory of approximately 500,000 inhabitants. The data includes not only the absences of these professionals but also the full roster of employees, allowing us to generate two reports: one with the complete list of professionals, and another focused solely on absences.
#
# - `rel_2141_CARGO`: Contains the job category or professional role of the employee.
# - `rel_2141_DT_ADMISSAO`: Date of admission or hiring.
# - `rel_2141_DT_DEMISSAO`: Date of termination or dismissal.
# - `rel_2141_prof_ID`: A unique identifier assigned to each employee by the organization.
# - `rel_2141_HORARIO`: The employee's work schedule.
# - `rel_2141_JORNADA`: The number of contracted hours per week.
# - `rel_2141_STATUS`: The employee's current status at the time the report was generated (e.g., Active, On Vacation, Terminated, etc.).
# - `rel_2141_LICINICIO`: Start date of a leave or absence.
# - `rel_2141_LICFIM`: End date of a leave, when applicable.
# - `rel_2141_AUSENCIA`: The type of absence (e.g., Vacation, Medical Leave, Maternity Leave).
#
# With Polars, data types are handled more robustly. For example, integer columns with null values (`rel_2141_CNES`) are correctly typed without being cast to float. We will ensure all date columns are explicitly cast to the correct datetime format.

# %%
# The Parquet reader correctly infers most date types. This block ensures that any
# columns that were read as strings are correctly converted to a Datetime type.
# This approach is robust and avoids corrupting already-correct data.

# List of all date columns we need to ensure are in Datetime format
all_date_cols = ['rel_2141_DT_ADMISSAO', 'rel_2141_DT_DEMISSAO', 'rel_2141_LICINICIO', 'rel_2141_LICFIM']

# Identify which of these columns are currently of String type
cols_to_convert = [c for c in all_date_cols if absence_report[c].dtype == pl.String]

# Apply the conversion only to the string columns, if any
if cols_to_convert:
    absence_report = absence_report.with_columns([
        pl.col(c)
        .str.to_datetime(format="%d/%m/%Y", strict=False) 
        for c in cols_to_convert
    ])

display_message(f"The data type of 'rel_2141_DT_DEMISSAO' now is **{absence_report['rel_2141_DT_DEMISSAO'].dtype}**", level=5)
# Out:
# ##### The data type of 'rel_2141_DT_DEMISSAO' now is **Datetime(time_unit='us', time_zone=None)**

# %% [markdown]
# ### Excluding Non-Eligible Professionals
#
# In this step, we filter out professionals who should not be included in the current absence report for various reasons. After applying these exclusion criteria, we generate a separate report of the excluded professionals for further review, which is saved as a Parquet file. This report is useful for understanding who was excluded and why, ensuring transparency and traceability in the data processing.

# %%
# Define the exclusion criteria for professionals based on their employment status.
status_exclusion_criteria = pl.col('rel_2141_STATUS').is_in([
    'Apos. por Incapacidade Permanente',
    'Licença s/venc',
    'Contrato de Trabalho Suspenso',
    'Admissão prox.mês',
])

# Display the counts of professionals excluded based on their status
display_df(
    absence_report
    .filter(status_exclusion_criteria)
    .group_by('rel_2141_STATUS')
    .len()
    .rename({'rel_2141_STATUS': 'STATUS', 'len': 'COUNT'})
    .sort('COUNT', descending=True)
)

# Define criteria for professionals without a CNES (typically administrative staff)
cnes_missing_criteria = pl.col('rel_2141_CNES').is_null()

# Display the counts of professionals excluded due to missing CNES
display_df(
    absence_report
    .filter(cnes_missing_criteria)
    .group_by('rel_2141_UNIDADE')
    .len()
    .rename({'rel_2141_UNIDADE': 'FACILITY', 'len': 'COUNT'})
    .sort('COUNT', descending=True)
)

# Combine both exclusion criteria
exclusion_filter = status_exclusion_criteria | cnes_missing_criteria

# Create a DataFrame of excluded professionals and save it to a Parquet file
excluded_professionals = absence_report.filter(exclusion_filter)
excluded_professionals.sort(['rel_2141_CNES', 'rel_2141_STATUS', 'rel_2141_NOME']).write_parquet(EXCLUDED_PROFESSIONALS_PATH)

# Update the main DataFrame by removing the excluded professionals
absence_report = absence_report.filter(~exclusion_filter)

# Create the initial professional report from the cleaned data
professional_report_initial = (
    absence_report
    .select(PROFESSIONALS_COLS)
    .sort(['rel_2141_CNES', 'rel_2141_CARGO', 'rel_2141_JORNADA', 'rel_2141_NOME'])
)
# Out:
# shape: (4, 2)
# ┌─────────────────────────────────┬───────┐
# │ STATUS                          ┆ COUNT │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ Admissão prox.mês               ┆ 37    │
# │ Apos. por Incapacidade Permane… ┆ 5     │
# │ Licença s/venc                  ┆ 2     │
# │ Contrato de Trabalho Suspenso   ┆ 2     │
# └─────────────────────────────────┴───────┘
# shape: (1, 2)
# ┌─────────────────────────────────┬───────┐
# │ FACILITY                        ┆ COUNT │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ COORDENACAO TECNICA ADMINISTRA… ┆ 63    │
# └─────────────────────────────────┴───────┘

# %% [markdown]
# ### Data Consolidation: Professional Records
#
# In this step, we consolidate the records of professionals based on their unique identifier (`rel_2141_prof_ID`). The goal is to ensure that each professional has a single, consistent record in the final dataset, while identifying and handling any discrepancies in the data.

# %%
# Create a temporary DataFrame with a resolved termination date for each professional.
# This backfills null dates if, and only if, there is a single unique non-null date for a given professional.
report_with_resolved_dates = professional_report_initial.with_columns(
    pl.when(pl.col("rel_2141_DT_DEMISSAO").drop_nulls().n_unique().over("rel_2141_prof_ID") == 1)
    .then(pl.col("rel_2141_DT_DEMISSAO").max().over("rel_2141_prof_ID"))
    .otherwise(pl.col("rel_2141_DT_DEMISSAO"))
    .alias("rel_2141_DT_DEMISSAO")
)

# Identify unique records after resolving the dates. Inconsistent records will result in multiple unique rows per professional.
distinct_records = report_with_resolved_dates.unique()

# Count the number of unique configurations for each professional
record_counts = distinct_records.group_by("rel_2141_prof_ID").len()

# Valid professionals are those with exactly one unique record configuration
valid_ids = record_counts.filter(pl.col("len") == 1).select("rel_2141_prof_ID")

# Invalid professionals are those with more than one configuration, indicating an unresolvable inconsistency
invalid_ids = record_counts.filter(pl.col("len") > 1).select("rel_2141_prof_ID")

# The final professional report contains only the unique, valid records
professional_report = distinct_records.join(valid_ids, on="rel_2141_prof_ID", how="inner")

# The consolidation failures report contains all original records for the professionals identified as invalid
invalid_groups = professional_report_initial.join(invalid_ids, on="rel_2141_prof_ID", how="inner")
invalid_groups.write_parquet(CONSOLIDATION_FAILURES_PATH)

# Display any records that failed consolidation using the custom formatting function
display_df(invalid_groups)
# Out:
# shape: (2, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ rel_2141_ ┆ rel_2141_ ┆ rel_2141_ ┆ rel_2141_ ┆ … ┆ rel_2141_ ┆ rel_2141_ ┆ rel_2141_ ┆ rel_2141 │
# │ CNES      ┆ UNIDADE   ┆ NOME      ┆ CARGO     ┆   ┆ prof_ID   ┆ HORARIO   ┆ JORNADA   ┆ _STATUS  │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ i64       ┆ str       ┆ i64       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2787806   ┆ UBS       ┆ MILDRID   ┆ AUXILIAR  ┆ … ┆ 40000351  ┆ 10:00 -   ┆ 40        ┆ Demitido │
# │           ┆ JARDIM    ┆ HEBBORN   ┆ ADMINISTR ┆   ┆           ┆ 13:00 -   ┆           ┆          │
# │           ┆ SAO       ┆           ┆ ATIVO     ┆   ┆           ┆ 14:00 -   ┆           ┆          │
# ...

# %% [markdown]
# ---
# ### Business Rules Processing for Absences
#
# This block applies key business rules to clean and correct inconsistencies in the absence data:
#
# 1. **Initial Data Cleaning**: We remove records that do not represent actual absences. First, we exclude entries with no absence start date, followed by the removal of records indicating termination (`Demitido`, `Demitidos`, `Aviso Prévio`).
#
# 2. **Inconsistency Correction**: A widespread issue in the dataset is the inconsistent classification of medical leave. Absences under 15 days are sometimes incorrectly marked as "Af.Previdência" (Social Security leave) instead of "Atestado" (Medical Certificate). We correct this by reclassifying those under 15 days as "Atestado."
#
# 3. **Manual Review Flagging**: Medical certificates that extend beyond 15 days are flagged for manual review, as these should potentially be classified as Social Security leave. To highlight these cases, the absence type is updated to "Atestado (Acima de 15 dias)."

# %%
# 1. Initial Data Cleaning
initial_count = absence_report.height

# Filter for records that represent actual absences by requiring a start date (LICINICIO)
# and excluding termination-related statuses.
absence_report_filtered = absence_report.filter(
    pl.col('rel_2141_LICINICIO').is_not_null() &
    ~pl.col('rel_2141_AUSENCIA').is_in(['Demitido', 'Demitidos', 'Aviso Prévio'])
)

excluded_rows = initial_count - absence_report_filtered.height
display_message(f"- Number of rows excluded: **{excluded_rows} _(out of {initial_count})_**")

# Calculate duration for business rule processing
absence_report_processed = absence_report_filtered.with_columns(
    ((pl.col('rel_2141_LICFIM') - pl.col('rel_2141_LICINICIO')).dt.total_days()).alias('absence_duration_days')
)

# 2. Inconsistency Correction
# This filter identifies "Social Security" leaves that have a defined end date,
# matching the exact logic from the original implementation.
social_security_filter = (
    (pl.col('rel_2141_AUSENCIA') == 'Af.Previdência') &
    (pl.col('rel_2141_LICFIM').is_not_null())
)

total_social_security = absence_report_processed.filter(social_security_filter).height
altered_rows = absence_report_processed.filter(social_security_filter & (pl.col('absence_duration_days') < 15)).height
altered_percentage = (altered_rows / total_social_security) * 100 if total_social_security > 0 else 0
display_message(f"- Percentage of rows changed from social security leave to regular medical leave: **{altered_percentage:.2f}% ({altered_rows}/{total_social_security} filtered)**")

# 3. Manual Review Flagging & Application of all rules
absence_report_final = absence_report_processed.with_columns(
    pl.when(social_security_filter & (pl.col('absence_duration_days') < 15))
    .then(pl.lit('Atestado'))
    .when((pl.col('rel_2141_AUSENCIA') == 'Atestado') & (pl.col('absence_duration_days') > 15))
    .then(pl.lit('Atestado (Acima de 15 dias)'))
    .otherwise(pl.col('rel_2141_AUSENCIA'))
    .alias('rel_2141_AUSENCIA')
).drop('absence_duration_days')

# Identify professionals with absences flagged for manual review
professionals_with_manual_review = absence_report_final.filter(
    pl.col('rel_2141_AUSENCIA') == 'Atestado (Acima de 15 dias)'
).get_column('rel_2141_prof_ID').unique()

manual_review_filter = pl.col('rel_2141_prof_ID').is_in(professionals_with_manual_review)
manual_review_count = absence_report_final.filter(manual_review_filter).height
display_message(f"- Number of rows flagged for manual review (usually maternity leave): **{manual_review_count}**")
display_df(absence_report_final.filter(manual_review_filter).head(4))

# Prepare the absence report for the next step and export the intermediate result
absence_report = absence_report_final.sort(['rel_2141_prof_ID', 'rel_2141_LICINICIO', 'rel_2141_LICFIM'])
absence_report.write_parquet(ABSENCES_CONSOLIDATED_PATH)
# Out:
# #### - Number of rows excluded: **1321 _(out of 2680)_**
# #### - Percentage of rows changed from social security leave to regular medical leave: **98.77% (641/649 filtered)**
# #### - Number of rows flagged for manual review (usually maternity leave): **8**
# shape: (4, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ rel_2141_ ┆ rel_2141_ ┆ rel_2141_ ┆ rel_2141_ ┆ … ┆ rel_2141_ ┆ rel_2141_ ┆ rel_2141_ ┆ rel_2141 │
# │ CNES      ┆ UNIDADE   ┆ NOME      ┆ CARGO     ┆   ┆ STATUS    ┆ LICINICIO ┆ LICFIM    ┆ _AUSENCI │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ A        │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ str       ┆ date      ┆ date      ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# ...

# %% [markdown]
# ### Consolidating Uninterrupted Absences
#
# To streamline the analysis of employee absences, we consolidate uninterrupted periods of the same type of absence. This means that if an employee has consecutive days of the same absence type (e.g., continuous medical leave), these are combined into a single entry. This process simplifies the data, making it easier to analyze and interpret the length and frequency of absences without redundancy.

# %%
# absence_report_data_processing.ipynb
# Display a sample of absences for one employee before consolidation to illustrate the process.
display_message("Absences of a single employee before consolidation:")
display_df(
    absence_report
    .filter(pl.col('rel_2141_prof_ID') == 40002244)
    .select(['rel_2141_prof_ID', 'rel_2141_LICINICIO', 'rel_2141_LICFIM', 'rel_2141_AUSENCIA'])
)

# Sort data to ensure correct continuity checks
absence_report_sorted = absence_report.sort(['rel_2141_prof_ID', 'rel_2141_AUSENCIA', 'rel_2141_LICINICIO'])

# Identify the start of a new absence block. A block starts if:
# 1. The professional ID changes.
# 2. The absence type changes.
# 3. The current start date is not one day after the previous end date.
absence_blocks = absence_report_sorted.with_columns(
    (
        (pl.col('rel_2141_prof_ID') != pl.col('rel_2141_prof_ID').shift(1)) |
        (pl.col('rel_2141_AUSENCIA') != pl.col('rel_2141_AUSENCIA').shift(1)) |
        (pl.col('rel_2141_LICINICIO') != pl.col('rel_2141_LICFIM').shift(1) + pl.duration(days=1))
    ).fill_null(True).alias('is_block_start')
).with_columns(
    pl.col('is_block_start').cum_sum().over(['rel_2141_prof_ID', 'rel_2141_AUSENCIA']).alias('block_id')
)

# Group by the identified blocks and aggregate to get the consolidated period
absence_report_consolidated = absence_blocks.group_by(['rel_2141_prof_ID', 'rel_2141_AUSENCIA', 'block_id']).agg(
    pl.col('rel_2141_LICINICIO').min().alias('rel_2141_LICINICIO'),
    pl.col('rel_2141_LICFIM').max().alias('rel_2141_LICFIM')
).drop('block_id').sort(['rel_2141_prof_ID', 'rel_2141_LICINICIO'])

absence_report = absence_report_consolidated

# Display the same employee's absences after consolidation
display_message("Absences after consolidation:")
display_df(
    absence_report
    .filter(pl.col('rel_2141_prof_ID') == 40002244)
)
# Out:
# #### Absences of a single employee before consolidation:
# shape: (7, 4)
# ┌──────────────────┬────────────────────┬─────────────────┬───────────────────┐
# │ rel_2141_prof_ID ┆ rel_2141_LICINICIO ┆ rel_2141_LICFIM ┆ rel_2141_AUSENCIA │
# │ ---              ┆ ---                ┆ ---             ┆ ---               │
# │ i64              ┆ date               ┆ date            ┆ str               │
# ╞══════════════════╪════════════════════╪═════════════════╪═══════════════════╡
# │ 40002244         ┆ 2024-08-02         ┆ 2024-08-02      ┆ Atestado          │
# │ 40002244         ┆ 2024-08-03         ┆ 2024-08-03      ┆ Atestado          │
# │ 40002244         ┆ 2024-08-05         ┆ 2024-08-05      ┆ Atestado          │
# │ 40002244         ┆ 2024-08-08         ┆ 2024-08-08      ┆ Atestado          │
# │ 40002244         ┆ 2024-08-12         ┆ 2024-08-12      ┆ Atestado          │
# │ 40002244         ┆ 2024-08-13         ┆ 2024-08-13      ┆ Atestado          │
# ...

# %% [markdown]
# ---
# ### Automating the Generation of Legal Absences
#
# One of the key motivations for generating the `LEGAL_ABSENCES` column is to streamline the documentation process and automate the manual verification of absence data for each professional.
#
# Previously, each healthcare unit manager was responsible for manually compiling the legal absences for their staff, which resulted in a high number of errors and inconsistencies. By centralizing and automating this process through the pipeline, we not only reduce manual effort but also ensure that the absence data is accurate and standardized across the entire organization.
#
# Below is a table showing a selection of manually generated records, which highlight how inefficient and error-prone the previous manual process was in January, 2024. The automation processes developed throughout the contract are only made possible through this type of pipeline, as it allows for vectorized operations where business rules can be applied automatically across the entire dataset:
#
# > Consultório na rua - ABONO GESTACIONAL DE 20/12 A 25/12 E 26/12 LICENÇA MATERNIDADE\nLicença Mater. 26/12/2023 - 20/10/2024
# > AMA CANGAÍBA - ATIVIDADE TEÓRICA DE 05/01; 12/01; 19/01; 26/01/2024
# > UBS CANGAÍBA - Licença gestante\nAtestado médico de 15 a 15/01 - 2 dias\nAtestado médico de 18 a 30/01 - 13 dias
# > ATESTADO - 03/01/24; ATESTADO - 15 A 18/01/24\nATESTADO 31/01/2024
# > FÉRIAS - 03 A 22/01/24, FOGA SAÚDE - 23/01/24
# > Atestado 04.01 a 06.01 / 17 e 18.01 / 24 a 26.01 / 29.01
# > AFASTAMENTO GESTACIONAL EM 04/09 PREVISÃO DE PARTO PARA 17/04/2024\nLicença Mater. 04/09/2023 - 29/06/2024
# > 11/01 e 12/01 3h BH; 15/01 BH 8h\nFérias 31/01 a 09/02/2024\nInércia Clínica no Risco Cardiovascular
# > FERIAS 19/12/2023 A 02/01/2024 (15 DIAS)\nATESTADO 17/01/2024 A 19/01/2024 (3 DIAS)\nAFASTAMENTO GESTACIONAL COM INÍCIO EM 22/01/2024 A 16/11/2024 (DPP 20/09/2024)
# > Atestado 26/01/2024 - 30/01/2024

# %%
# Prepare absence data for text generation by formatting dates into a 'DD/MM/YYYY' string format.
absences_with_formatted_text = absence_report.with_columns(
    start_date_str = pl.col('rel_2141_LICINICIO').dt.strftime('%d/%m/%Y'),
    end_date_str = pl.col('rel_2141_LICFIM').dt.strftime('%d/%m/%Y'),
).with_columns(
    # Build the descriptive text for each absence record using a when/then/otherwise expression.
    absence_text = pl.concat_str([
        pl.col('rel_2141_AUSENCIA'),
        pl.lit(': '),
        pl.when(pl.col('rel_2141_LICFIM').is_null())
        .then(pl.concat_str([pl.lit('A partir de '), pl.col('start_date_str')]))
        .when(pl.col('start_date_str') == pl.col('end_date_str'))
        .then(pl.col('start_date_str'))
        .otherwise(pl.concat_str([pl.col('start_date_str'), pl.lit(' a '), pl.col('end_date_str')]))
    ])
)

# Group by professional ID and aggregate all absence texts directly into a final, pipe-separated string.
legal_absences_agg = absences_with_formatted_text.group_by('rel_2141_prof_ID').agg(
    pl.col('absence_text').implode().list.join(' | ').alias('LEGAL_ABSENCES')
)

# Join the aggregated legal absences back to the main professional report and sort the final result.
professional_report_final = professional_report.join(
    legal_absences_agg, 
    on='rel_2141_prof_ID', 
    how='left'
).sort('rel_2141_prof_ID')

# Save the final report to a Parquet file
professional_report_final.write_parquet(PROFESSIONALS_CONSOLIDATED_PATH)

# Display a sample of the generated LEGAL_ABSENCES column
display(
    professional_report_final
    .filter(pl.col('LEGAL_ABSENCES').is_not_null())
    .select(['rel_2141_prof_ID', 'LEGAL_ABSENCES'])
    .head(10)
)

# Create a clean, "info-like" summary of the final DataFrame
info_df = pl.DataFrame({
    "Column": professional_report_final.columns,
    "Non-Null Count": professional_report_final.select(pl.all().is_not_null().sum()).row(0),
    "Dtype": professional_report_final.dtypes
})

# Use Polars Config to temporarily set the display rows to unlimited (-1)
# ensuring the entire info_df is printed without truncation.
with pl.Config(tbl_rows=-1):
    display(info_df)
# Out:
# shape: (10, 2)
# ┌──────────────────┬─────────────────────────────────┐
# │ rel_2141_prof_ID ┆ LEGAL_ABSENCES                  │
# │ ---              ┆ ---                             │
# │ i64              ┆ list[str]                       │
# ╞══════════════════╪═════════════════════════════════╡
# │ 40000013         ┆ ["Atestado: 15/08/2024"]        │
# │ 40000016         ┆ ["Atestado: 16/08/2024 a 20/08… │
# │ 40000023         ┆ ["Férias: 10/07/2024 a 08/08/2… │
# │ 40000025         ┆ ["Atestado: 20/08/2024 a 24/08… │
# │ 40000028         ┆ ["Atestado: 04/09/2024"]        │
# │ 40000039         ┆ ["Af.Previdência: A partir de … │
# │ 40000056         ┆ ["Férias: 05/08/2024 a 03/09/2… │
# │ 40000057         ┆ ["Atestado: 09/08/2024 a 13/08… │
# │ 40000069         ┆ ["Atestado: 27/08/2024 a 31/08… │
# │ 40000082         ┆ ["Atestado: 21/08/2024 a 23/08… │
# └──────────────────┴─────────────────────────────────┘
# shape: (11, 3)
# ...
